# %%
# %pip install fsspec s3fs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install amazon-braket-sdk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 17.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [41 lines of output]
#       running egg_info
#       creating /tmp/pip-pip-egg-info-sar3kwtw/antlr4_python3_runtime.egg-info
#       writing /tmp/pip-pip-egg-info-sar3kwtw/antlr4_python3_runtime.egg-info/PKG-INFO
#       writing dependency_links to /tmp/pip-pip-egg-info-sar3kwtw/antlr4_python3_runtime.egg-info/dependency_links.txt
#       writing requirements to /tmp/pip-pip-egg-info-sar3kwtw/antlr4_python3_runtime.egg-info/requires.txt
#       writing top-level names to /tmp/pip-pip-egg-info-sar3kwtw/antlr4_python3_runtime.egg-info/top_level.txt
#       writing manifest file '/tmp/pip-pip-egg-info-sar3kwtw/antlr4_python3_runtime.egg-info/SOURCES.txt'
# ...

# %%
import boto3
import pandas as pd
from io import StringIO
# Initialize a session using Amazon S3
s3 = boto3.client('s3')
# Define the bucket name and the object key
bucket_name = 'amazon-braket-eng-dev'
object_key = 'original-run-results/002f95e9-3deb-4c1c-85c5-7253b48859c8/results.json'
# Get the object from the S3 bucket
response = s3.get_object(Bucket=bucket_name, Key=object_key)

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '12DP1Z40QQEG6W8T',
#   'HostId': 'CKf/IKebk5CZbruNjeyR8rIiuHCRYnon4+Uw0AeUD/9jsdxNbRa3+OEM/e27bRCIraK/5wCnQseWu6eCqFHnVw==',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'CKf/IKebk5CZbruNjeyR8rIiuHCRYnon4+Uw0AeUD/9jsdxNbRa3+OEM/e27bRCIraK/5wCnQseWu6eCqFHnVw==',
#    'x-amz-request-id': '12DP1Z40QQEG6W8T',
#    'date': 'Sat, 31 Aug 2024 01:05:07 GMT',
#    'last-modified': 'Thu, 14 Mar 2024 23:57:29 GMT',
#    'etag': '"0416bccba3bbf8a0db3efcbf6685d889"',
#    'x-amz-server-side-encryption': 'AES256',
#    'accept-ranges': 'bytes',
#    'content-type': 'application/json',
#    'server': 'AmazonS3',
#    'content-length': '2103'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2024, 3, 14, 23, 57, 29, tzinfo=tzutc()),
#  'ContentLength': 2103,
#  'ETag': '"0416bccba3bbf8a0db3efcbf6685d889"',
#  'ContentType': 'application/json',
#  'ServerSideEncryption': 'AES256',
#  'Metadata': {},
# ...

# %%
# Function to list all files in an S3 bucket
def list_files(bucket_name):
    files = []
    response = s3.list_objects_v2(Bucket=bucket_name)
    
    if 'Contents' in response:
        for item in response['Contents']:
            files.append(item['Key'])
    
    return files

# Function to read a file from S3
def read_file(bucket_name, file_key):
    obj = s3.get_object(Bucket=bucket_name, Key=file_key)
    return obj['Body'].read().decode('utf-8')

# Example usage
bucket_name = 'amazon-braket-eng-dev'

# List all files in the bucket
files = list_files(bucket_name)
print(f'Files in {bucket_name}: {files}')
# Out:
# Files in amazon-braket-eng-dev: ['original-run-results/', 'original-run-results/002f95e9-3deb-4c1c-85c5-7253b48859c8/results.json', 'original-run-results/00345b21-e698-4dff-8f14-9f67cfee8674/results.json', 'original-run-results/00828b39-d57a-4543-8ff5-8ebad4ad1f25/results.json', 'original-run-results/00a82046-0372-4ddc-af97-261ec6d3fe65/results.json', 'original-run-results/00e8dbcd-eb75-49e2-ba7f-2b2467999da1/results.json', 'original-run-results/00eedac6-1952-4361-bdbf-be1945d88ff5/results.json', 'original-run-results/0105b433-917e-4830-b6f7-fa60ca1b0bde/results.json', 'original-run-results/010b55b8-815c-4452-8432-fa34baf97e10/results.json', 'original-run-results/010dbc19-9bd8-45eb-ac86-5ce500c6390e/results.json', 'original-run-results/01383032-01fa-4089-a105-b8867507b186/results.json', 'original-run-results/01ca9bbe-7595-41d9-aa87-86a98f16afcb/results.json', 'original-run-results/02057fd9-c417-47a2-b790-8d282f0be197/results.json', 'original-run-results/0328027d-c005-4949-98dc-013d34
# ...

# %%
print (len(files))
# Out:
# 1000

# %%
print(counter)

# %%
import json
def read_json_from_s3(bucket, key):
    try:
        # Get the object from S3
        response = s3.get_object(Bucket=bucket, Key=key)
        # Read the content of the object
        content = response['Body'].read().decode('utf-8')
        # Parse JSON content
        data = json.loads(content)
        return data
    except Exception as e:
        print(f"Error reading {key} from bucket {bucket}: {e}")
        return None

# Read and print the content of each JSON file
counter=0
for file_key in files:
    the_result = read_json_from_s3(bucket_name, file_key)
    if the_result and "measurementProbabilities" in the_result:
        counter+=1
        #print(the_result)
        measurement_probabilities = the_result["measurementProbabilities"]
        #print(measurement_probabilities)
        #print(f"Content of {file_key}:")
        #print(json.dumps(the_result, indent=2))
        #print('-------------------')
# Out:
# Error reading original-run-results/ from bucket amazon-braket-eng-dev: Expecting value: line 1 column 1 (char 0)

# %%
reference_table={
}

# %%
from braket.circuits import Circuit
import itertools as it
import random
def cnot_sequence(circuit_length, input_bits='00'):
    c = Circuit()
    
    # encode the input
    if input_bits[0] == '1': c.x(0)
    if input_bits[1] == '1': c.x(1)
        
    # create the CNOT sequence
    for idx in range(circuit_length):
        if idx % 2 == 0: c.cnot(0, 1)
        if idx % 2 == 1: c.cnot(1, 0)
            
    return c

possible_input_bits      = ('00', '01', '10', '11')
possible_circuit_lengths = (1, 2, 3, 4, 5, 6)
possible_keys = list(it.product(possible_input_bits, possible_circuit_lengths))

circuit_pool             = {}
for input_bits in possible_input_bits:
    for circuit_length in possible_circuit_lengths:
        circuit = cnot_sequence(circuit_length, input_bits=input_bits)
        circuit_pool[(input_bits, circuit_length)] = circuit

def generate_circuit_batch(size):
    random_keys = random.choices(possible_keys, k=size)
    return [(key, circuit_pool[key]) for key in random_keys]

print("EXAMPLE CIRCUIT BATCH")
print("_" * 24)
for key, circuit in generate_circuit_batch(5):
    print()
    print("input_bits={}, length={}".format(*key))
    print("-" * 24)
    print(circuit)
    print("_" * 24)
# Out:
# EXAMPLE CIRCUIT BATCH
# ________________________
#
# input_bits=01, length=2
# ------------------------
# T  : │  0  │  1  │  2  │
#                   ┌───┐
# q0 : ─────────●───┤ X ├─
#               │   └─┬─┘
#       ┌───┐ ┌─┴─┐   │
# q1 : ─┤ X ├─┤ X ├───●───
#       └───┘ └───┘
# T  : │  0  │  1  │  2  │
# ________________________
#
# input_bits=01, length=1
# ------------------------
# T  : │  0  │  1  │
#
# q0 : ─────────●───
#               │
#       ┌───┐ ┌─┴─┐
# q1 : ─┤ X ├─┤ X ├─
#       └───┘ └───┘
# T  : │  0  │  1  │
# ________________________
#
# input_bits=00, length=2
# ------------------------
# T  : │  0  │  1  │
#             ┌───┐
# q0 : ───●───┤ X ├─
#         │   └─┬─┘
#       ┌─┴─┐   │
# q1 : ─┤ X ├───●───
#       └───┘
# T  : │  0  │  1  │
# ________________________
#
# input_bits=00, length=6
# ------------------------
# T  : │  0  │  1  │  2  │  3  │  4  │  5  │
#             ┌───┐       ┌───┐       ┌───┐
# q0 : ───●───┤ X ├───●───┤ X ├───●───┤ X ├─
# ...

# %%
from braket.circuits import Circuit, Observable
from braket.devices import LocalSimulator

# %%
from braket.aws import AwsQuantumTask
from botocore.exceptions import ClientError

# %%
# we should save Save task IDs to a JSON file
'''
task_ids = [task.id for task in tasks]
with open('task_ids.json', 'w') as f:
    json.dump(task_ids, f)
    
import json
from braket.aws import AwsQuantumTask

# Load task IDs from the JSON file
with open('task_ids.json', 'r') as f:
    task_ids = json.load(f)
    
'''

# %%
task_ids= ['arn:aws:braket:us-east-1:835581428919:quantum-task/4dba09a5-273f-4d85-a9ce-1851257f4a37', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/c195554b-bfee-4512-acb3-923c60c0f6d0', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/b584f81f-71a1-4d31-b49f-c1cf6e0fef22', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/230ccce7-1f0f-4af3-bb20-2e63aeb62359', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/c4a024e3-8bc4-4c7d-af41-aadf20a31374', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/b13800fa-d2f0-47ae-b00e-a80187dda729', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/4c4fcef0-f112-4b0a-9ed7-72ca147f54a0',
          'arn:aws:braket:us-east-1:835581428919:quantum-task/ca2e5968-e539-46aa-b525-715ad87689f0', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/14fd30c0-a65d-41a3-94fc-6adf9705ab88', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/048b85de-db86-48ac-9613-16bb3dc52f97', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/80fe8eef-6d04-4209-bd93-bbefe6eaca29', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/1b7e8851-35af-494c-b10e-a8a09a4f3680', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/ecfda520-1a60-4e42-a376-564944cb6179', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/1a6845d9-4f76-48af-99fb-f5b307afc051', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/ed6d2fb7-f627-4547-ac9b-7f856d6bdb23',
          'arn:aws:braket:us-east-1:835581428919:quantum-task/304872fe-2b52-4319-a36c-1a41927444f6', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/0a814332-4ef1-438c-9900-65c6fbb0e52d', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/f7d37725-06dd-4380-878d-4aa4c0b76a62', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/772615cc-1148-45e6-8c97-ad9194da1302', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/6d2e83cd-326b-43ae-b6a0-bb3355011f92', 
          'arn:aws:braket:us-east-1:835581428919:quantum-task/d45e5df8-71ec-4c66-bea1-2f60713791a8', 'arn:aws:braket:us-east-1:835581428919:quantum-task/8bc6da3b-b560-464b-8f40-c2548d5e8f74', 'arn:aws:braket:us-east-1:835581428919:quantum-task/a78fc537-1af4-44f4-a96b-e62b47b98678', 'arn:aws:braket:us-east-1:835581428919:quantum-task/7325da67-6c66-4eee-872b-ee590b72a2df', 'arn:aws:braket:us-east-1:835581428919:qu
quantum-task/30ad9c6b-563d-4af0-9ae7-7f60fe7b80e6', 'arn:aws:braket:us-east-1:835581428919:quantum-task/fd6f6e4e-39a9-48e8-a518-6af81a00ac79', 'arn:aws:braket:us-east-1:835581428919:quantum-task/f7d37e41-b2e7-41df-a7f7-94ad583b4cc8', 'arn:aws:braket:us-east-1:835581428919:quantum-task/2527ea6b-64e9-46ac-aef4-95113f5c5e96', 'arn:aws:braket:us-east-1:835581428919:quantum-task/98a41729-707f-434e-b154-8af3736df1f7', 'arn:aws:braket:us-east-1:835581428919:quantum-task/fe0907cc-87da-46f4-a086-2bc59c623832', 'arn:aws:braket:us-east-1:835581428919:quantum-task/c02c1544-52b3-489f-990a-eeab65852b8a', 'arn:aws:braket:us-east-1:835581428919:quantum-task/c02837bc-5f12-4392-9292-63dd6807fa8a', 'arn:aws:braket:us-east-1:835581428919:quantum-task/2ed716e4-a235-4965-bfa4-86e13e3b18b0', 'arn:aws:braket:us-east-1:835581428919:quantum-task/3e5b706b-288b-4710-a51f-8ba65869c878', 'arn:aws:braket:us-east-1:835581428919:quantum-task/bb8ca150-4d7c-4732-9648-5909195bea3e', 'arn:aws:braket:us-east-1:835581428919:quantum-task/c449b6f0-4666-4ce0-81c1-a07c67489689', 'arn:aws:braket:us-east-1:835581428919:quantum-task/b6e6b047-84b0-41f2-8ec7-0c5c2e880e3b', 'arn:aws:braket:us-east-1:835581428919:quantum-task/551433c6-4ab6-4a00-86f2-81ecd4db3f54', 'arn:aws:braket:us-east-1:835581428919:quantum-task/f073fd09-f270-40a7-ab67-f7dfb73b7bbd', 'arn:aws:braket:us-east-1:835581428919:quantum-task/26b3ddc5-2e90-4163-b5cf-2d863d32758c', 'arn:aws:braket:us-east-1:835581428919:quantum-task/2ff2bc06-939f-4356-843f-8b25473ef40e', 'arn:aws:braket:us-east-1:835581428919:quantum-task/53831268-2b4b-4d11-9a66-0d7f3130393e', 'arn:aws:braket:us-east-1:835581428919:quantum-task/d14f9297-cd82-4ffb-b745-f40cb14c80a8', 'arn:aws:braket:us-east-1:835581428919:quantum-task/2d47380a-712f-435d-a84d-dbbc64837eb6', 'arn:aws:braket:us-east-1:835581428919:quantum-task/105d12e7-590a-4c08-a001-76d4fd6de7cd', 'arn:aws:braket:us-east-1:835581428919:quantum-task/d67209bd-eaa5-4098-8680-d3f8c37a9ec3']

# %%
task_ids[:5]
# Out:
# ['arn:aws:braket:us-east-1:835581428919:quantum-task/4dba09a5-273f-4d85-a9ce-1851257f4a37',
#  'arn:aws:braket:us-east-1:835581428919:quantum-task/c195554b-bfee-4512-acb3-923c60c0f6d0',
#  'arn:aws:braket:us-east-1:835581428919:quantum-task/b584f81f-71a1-4d31-b49f-c1cf6e0fef22',
#  'arn:aws:braket:us-east-1:835581428919:quantum-task/230ccce7-1f0f-4af3-bb20-2e63aeb62359',
#  'arn:aws:braket:us-east-1:835581428919:quantum-task/c4a024e3-8bc4-4c7d-af41-aadf20a31374']

# %%
region = 'us-east-1'  # Change to your AWS region
s3_folder = ("amazon-braket-eng-dev", "yuval_mwe_preliminary")

# %%
for task_id in task_ids:
    try:
        task = AwsQuantumTask(task_id)
        tasks.append(task)
    except ClientError as e:
        if e.response['Error']['Code'] == 'ResourceNotFoundException':
            print(f"Task {task_id} not found or has expired.")
        else:
            print(f"An error occurred: {e}")

# Optionally, fetch results or other metadata for available tasks
results = []
for task in tasks:
    try:
        result = task.result()
        results.append(result)
    except ClientError as e:
        print(f"Failed to fetch result for task {task.id}: {e}")
# Out:
# Failed to fetch result for task arn:aws:braket:us-east-1:835581428919:quantum-task/4dba09a5-273f-4d85-a9ce-1851257f4a37: An error occurred (ResourceNotFoundException) when calling the GetQuantumTask operation: Quantum task 4dba09a5-273f-4d85-a9ce-1851257f4a37 not found
# Failed to fetch result for task arn:aws:braket:us-east-1:835581428919:quantum-task/c195554b-bfee-4512-acb3-923c60c0f6d0: An error occurred (ResourceNotFoundException) when calling the GetQuantumTask operation: Quantum task c195554b-bfee-4512-acb3-923c60c0f6d0 not found
# Failed to fetch result for task arn:aws:braket:us-east-1:835581428919:quantum-task/b584f81f-71a1-4d31-b49f-c1cf6e0fef22: An error occurred (ResourceNotFoundException) when calling the GetQuantumTask operation: Quantum task b584f81f-71a1-4d31-b49f-c1cf6e0fef22 not found
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = []

for idx in range(len(tasks)):
    print(idx)
    #print('DEBUG')
    the_task   = tasks[idx]
    #print('DEBUG')
    task_id    = the_task.id
    #print('DEBUG')
    the_result = the_task.result()
    #print('DEBUG')
    
    start_time   = pd.to_datetime(the_result.task_metadata.createdAt)
    end_time     = pd.to_datetime(the_result.task_metadata.endedAt)
    elapsed_time = end_time - start_time
    
    batch_member   = test_batch[idx]
    circuit_key    = batch_member[0]
    input_bits     = circuit_key[0]
    circuit_length = circuit_key[1]

    
    measurement_probabilities = the_result.measurement_probabilities
    correct_output            = reference_table[circuit_key]
    success_probability       = measurement_probabilities[correct_output]
    
    data.append((task_id,
                 input_bits,
                 circuit_length,
                 start_time,
                 end_time,
                 elapsed_time,
                 success_probability))

data = pd.DataFrame(data, columns=['id_string',
                                   'input_bits',
                                   'circuit_length',
                                   'start_time',
                                   'end_time',
                                   'elapsed_time',
                                   'success_probability'])
# Out:
# 0
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# Cell In[38], line 13
#      11 task_id    = the_task.id
#      12 #print('DEBUG')
# ---> 13 the_result = the_task.result()
#      14 #print('DEBUG')
#      16 start_time   = pd.to_datetime(the_result.task_metadata.createdAt)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/braket/aws/aws_quantum_task.py:421, in AwsQuantumTask.result(self)
#     419     return self._download_result()
#     420 try:
# --> 421     async_result = self.async_result()
#     422     return async_result.get_loop().run_until_complete(async_result)
#     423 except asyncio.CancelledError:
#     424     # Future was cancelled, return whatever is in self._result if anything
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/braket/aws/aws_quantum_task.py:449, in AwsQuantumTask.async_result(self)
# ...
